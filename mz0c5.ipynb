# %%
import pandas as pd
from tmt import (
    __read_spectra,
    __read_settings,
    __annotate_spectronaut_result,
    __get_key,
)

# %%
spectra = __read_spectra(
    "20250519_Astral1_Evo_TH071_TT_THIDmulti003_pool_DIA_mz0c5_3ng_ij80ms_1.mzML"
)
# Out:
# Total number of parsed spectra: 51048
# Number of MS1 spectra: 5672
# Number of MS2 spectra: 45376

# %%
settings = __read_settings("config.toml")

# %%
settings
# Out:
# {'window_size': 0.5,
#  'window_start': 400.0,
#  'window_end': 800.0,
#  'precursor_mass': 'FG.Mass',
#  'precursor_mz': 'FG.PrecMz',
#  'precursor_charge': 'FG.PrecMz',
#  'retention_time': 'EG.ApexRT',
#  'retention_time_in_sec': False,
#  'mz_tolerance': 0.02,
#  'rt_tolerance': 3.0,
#  'rt_window': 10.0,
#  'threshold': 0.7,
#  'noise': 0.1}

# %%
quant = __annotate_spectronaut_result("mz0c5.csv", spectra, settings, 2)
# Out:
# Annotating Spectronaut result...:   0%|                                              | 4/2631 [00:00<00:12, 205.35it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 quant = __annotate_spectronaut_result("mz0c5.csv", spectra, settings, 2)
#
# File ~\Documents\GitHub\TMT\tmt.py:442, in __annotate_spectronaut_result(spectronaut_filename, spectra, settings, verbose)
#     440     rt = rt * 60.0
#     441 # get corresponding MS2 spectrum for identification
# --> 442 spectrum = __get_ms2_spectrum(
#     443     prec_mz,
#     444     mz_tol,
#     445     rt,
#     446     rt_tol,
#     447     rt_window,
#     448     window_size_unidirectional,
#     449     filter_threshold,
#     450     noise_threshold,
#     451     spectra,
#     452     windows,
#     453     verbose,
#     454 )
#     455 # if a spectrum that passes the intensity filter is found -> quantify
#     456 if spectrum is not None:
#
# File ~\Documents\GitHub\TMT\tmt.py:341, in __get_ms2_spectrum(precursor_mz, mz_tol, retention_time, rt_tol, retention_time_ms1_window, window_size_unidirectional, filter_threshold, noise_threshold, spectra, windows, verbose)
#     339 if spectrum is None:
#     340     if verbose == 2:
# --> 341         raise RuntimeError(
#     342             f"Could not find a suitable retention time for precursor m/z {precursor_mz} and retention time {retention_time}."
#     343         )
#     344     elif verbose == 1:
#     345         warnings.warn(
#     346             RuntimeWarning(
#     347                 f"Could not find a suitable retention time for precursor m/z {precursor_mz} and retention time {retention_time}."
#     348             )
#     349         )
#
# RuntimeError: Could not find a suitable retention time for precursor m/z 480.9566345214844 and retention time 1944.122543334961.

# %%
df = pd.read_csv("mz0c5.csv", low_memory=False)

# %%
df.loc[4, "FG.PrecMz"]
# Out:
# 480.9566345214844

# %%
df.loc[4, "EG.ApexRT"] * 60
# Out:
# 1944.122543334961

# %%
df.loc[4, "R.FileName"]
# Out:
# '20250519_Astral1_Evo_TH071_TT_THIDmulti003_pool_DIA_mz0c5_3ng_ij80ms_1'

# %%
precursor = __get_key(df.loc[4, "FG.PrecMz"])
precursor
# Out:
# 4809566

# %%
for mz in spectra["ms2"].keys():
    if abs(mz - precursor) < __get_key(0.25):
        print(mz)
# Out:
# 4807500

# %%
rt_deltas = list()
for rt in spectra["ms2"][4807500].keys():
    rt_deltas.append(abs(__get_key(df.loc[4, "EG.ApexRT"] * 60.0) - rt))

# %%
rt_deltas = sorted(rt_deltas)

# %%
for i in range(5):
    print(rt_deltas[i] / 10000)
# Out:
# 22.9061
# 45.7399
# 91.5045
# 114.5298
# 160.2726
