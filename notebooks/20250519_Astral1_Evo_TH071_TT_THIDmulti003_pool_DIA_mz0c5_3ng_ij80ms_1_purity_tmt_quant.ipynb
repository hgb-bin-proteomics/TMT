# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("20250519_Astral1_Evo_TH071_TT_THIDmulti003_pool_DIA_mz0c5_3ng_ij80ms_1_purity_tmt_quant.xlsx")

# %%
fig, ax = plt.subplots(figsize=(4,3))

ax.hist(
    df["Co-Isolation Purity"],
    bins=100,
    density=False,
    histtype="bar",
    fill=True
)
ax.legend()
ax.set_ylabel("Number of identifications")
ax.set_xlabel("Purity")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 fig, ax = plt.subplots(figsize=(4,3))
# ----> 3 ax.hist(
#       4     df["Co-Isolation Purity"].dropna(),
#       5     bins=100,
#       6     density=False,
#       7     histtype="bar",
#       8     fill=True
#       9 )
#      10 ax.legend()
#      11 ax.set_ylabel("Number of identifications")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
# ...

# %%
df[df["Co-Isolation Purity"] > 1.0]["Co-Isolation Purity"]
# Out:
# 2510         inf
# 2548    5.437084
# 2807    1.059279
# 2862         inf
# 3070    1.080068
# 3098    1.456097
# 3196    4.866555
# 3361    1.085749
# 3482    1.013939
# 3548    1.165124
# 3851         inf
# 3958         inf
# 3959    9.477992
# 4682    1.314339
# 5287         inf
# Name: Co-Isolation Purity, dtype: float64
