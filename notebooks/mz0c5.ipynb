# %%
import pandas as pd
from tmt_spectronaut import (
    __read_spectra,
    __annotate_spectronaut_result,
)
from tmt_chimerys import __read_settings, __get_key

# %%
spectra = __read_spectra(
    "../20250519_Astral1_Evo_TH071_TT_THIDmulti003_pool_DIA_mz0c5_3ng_ij80ms_1.mzML"
)
# Out:
# Total number of parsed spectra: 51048
# Number of MS1 spectra: 5672
# Number of MS2 spectra: 45376

# %%
settings = __read_settings("../config.toml")

# %%
settings
# Out:
# {'window_size': 0.5,
#  'window_start': 400.0,
#  'window_end': 800.0,
#  'mz_tolerance': 0.02,
#  'rt_window': 10.0,
#  'threshold': 0.7,
#  'noise': 0.1}

# %%
quant = __annotate_spectronaut_result("mz0c5.csv", spectra, settings, 2)
# Out:
# Annotating Spectronaut result...:   0%|▏                                                                                               | 4/2631 [00:00<00:11, 235.28it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 quant = __annotate_spectronaut_result("mz0c5.csv", spectra, settings, 2)
#
# File ~\Documents\GitHub\TMT\notebooks\tmt_spectronaut.py:299, in __annotate_spectronaut_result(spectronaut_filename, spectra, settings, verbose)
#     293 windows = __get_windows(
#     294     float(settings["window_start"]),
#     295     float(settings["window_end"]),
#     296     float(settings["window_size"]),
#     297 )
#     298 # get corresponding MS2 spectrum for identification
# --> 299 spectrum_purity = __get_ms2_spectrum(
#     300     prec_mz,
#     301     mz_tol,
#     302     rt,
#     303     rt_tol,
#     304     rt_window,
# ...

# %%
df = pd.read_csv("mz0c5.csv", low_memory=False)

# %%
df.loc[4, "FG.PrecMz"]
# Out:
# np.float64(480.9566345214844)

# %%
df.loc[4, "EG.ApexRT"] * 60
# Out:
# np.float64(1944.122543334961)

# %%
df.loc[4, "R.FileName"]
# Out:
# '20250519_Astral1_Evo_TH071_TT_THIDmulti003_pool_DIA_mz0c5_3ng_ij80ms_1'

# %%
precursor = __get_key(df.loc[4, "FG.PrecMz"])
precursor
# Out:
# 4809566

# %%
for mz in spectra["ms2"].keys():
    if abs(mz - precursor) < __get_key(0.25):
        print(mz)
# Out:
# 4807500

# %%
rt_deltas = list()
for rt in spectra["ms2"][4807500].keys():
    rt_deltas.append(abs(__get_key(df.loc[4, "EG.ApexRT"] * 60.0) - rt))

# %%
rt_deltas = sorted(rt_deltas)

# %%
for i in range(5):
    print(rt_deltas[i] / 10000)
# Out:
# 22.9061
# 45.7399
# 91.5045
# 114.5298
# 160.2726
