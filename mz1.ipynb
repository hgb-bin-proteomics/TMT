# %%
import pandas as pd
from tmt import (
    __read_spectra,
    __read_settings,
    __annotate_spectronaut_result,
    __get_key,
)

# %%
spectra = __read_spectra(
    "20250519_Astral1_Evo_TH071_TT_THIDmulti003_pool_DIA_mz1_3ng_default_2.mzML"
)
# Out:
# Total number of parsed spectra: 93979
# Number of MS1 spectra: 6260
# Number of MS2 spectra: 87719

# %%
settings = __read_settings("config.toml")
settings["window_size"] = 1.0

# %%
settings
# Out:
# {'window_size': 1.0,
#  'window_start': 400.0,
#  'window_end': 800.0,
#  'precursor_mass': 'FG.Mass',
#  'precursor_mz': 'FG.PrecMz',
#  'precursor_charge': 'FG.PrecMz',
#  'retention_time': 'EG.ApexRT',
#  'retention_time_in_sec': False,
#  'mz_tolerance': 0.02,
#  'rt_tolerance': 3.0,
#  'rt_window': 10.0,
#  'threshold': 0.7,
#  'noise': 0.1}

# %%
quant = __annotate_spectronaut_result("mz1.csv", spectra, settings, 2)
# Out:
# Annotating Spectronaut result...:   0%|                                            | 10/10448 [00:00<00:52, 198.08it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 quant = __annotate_spectronaut_result("mz1.csv", spectra, settings, 2)
#
# File ~\Documents\GitHub\TMT\tmt.py:445, in __annotate_spectronaut_result(spectronaut_filename, spectra, settings, verbose)
#     443     rt = rt * 60.0
#     444 # get corresponding MS2 spectrum for identification
# --> 445 spectrum = __get_ms2_spectrum(
#     446     prec_mz,
#     447     mz_tol,
#     448     rt,
#     449     rt_tol,
#     450     rt_window,
#     451     window_size_unidirectional,
#     452     filter_threshold,
#     453     noise_threshold,
#     454     spectra,
#     455     windows,
#     456     verbose,
#     457 )
#     458 # if a spectrum that passes the intensity filter is found -> quantify
#     459 if spectrum is not None:
#
# File ~\Documents\GitHub\TMT\tmt.py:341, in __get_ms2_spectrum(precursor_mz, mz_tol, retention_time, rt_tol, retention_time_ms1_window, window_size_unidirectional, filter_threshold, noise_threshold, spectra, windows, verbose)
#     339 if spectrum is None:
#     340     if verbose == 2:
# --> 341         raise RuntimeError(
#     342             f"Could not find a suitable retention time for precursor m/z {precursor_mz} and retention time {retention_time}."
#     343         )
#     344     elif verbose == 1:
#     345         warnings.warn(
#     346             RuntimeWarning(
#     347                 f"Could not find a suitable retention time for precursor m/z {precursor_mz} and retention time {retention_time}."
#     348             )
#     349         )
#
# RuntimeError: Could not find a suitable retention time for precursor m/z 555.9769897460938 and retention time 2848.630599975586.

# %%
df = pd.read_csv("mz1.csv", low_memory=False)

# %%
df.loc[10, "FG.PrecMz"]
# Out:
# 555.9769897460938

# %%
df.loc[10, "EG.ApexRT"] * 60
# Out:
# 2848.630599975586

# %%
df.loc[10, "R.FileName"]
# Out:
# '20250519_Astral1_Evo_TH071_TT_THIDmulti003_pool_DIA_mz1_3ng_default_2'

# %%
precursor = __get_key(df.loc[10, "FG.PrecMz"])
precursor
# Out:
# 5559770

# %%
for mz in spectra["ms2"].keys():
    if abs(mz - precursor) < __get_key(0.5):
        print(mz)
# Out:
# 5560026

# %%
rt_deltas = list()
for rt in spectra["ms2"][5560026].keys():
    rt_deltas.append(abs(__get_key(df.loc[10, "EG.ApexRT"] * 60.0) - rt))

# %%
rt_deltas = sorted(rt_deltas)

# %%
for i in range(5):
    print(rt_deltas[i] / 10000)
# Out:
# 6.0046
# 11.9801
# 24.0176
# 30.0223
# 42.1063
